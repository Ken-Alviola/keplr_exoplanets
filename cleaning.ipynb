# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', None)

from jupyterthemes import jtplot
jtplot.style(grid=False)

# %%
nasa_df = pd.read_csv('exoplanets_2018.csv')

# %%
nasa_df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              0              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...

# %%
nasa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   kepler_name        2359 non-null   object
#  3   koi_disposition    9564 non-null   object
#  4   koi_pdisposition   9564 non-null   object
#  5   koi_score          8054 non-null   float64
#  6   koi_fpflag_nt      9564 non-null   int64
#  7   koi_fpflag_ss      9564 non-null   int64
#  8   koi_fpflag_co      9564 non-null   int64
#  9   koi_fpflag_ec      9564 non-null   int64
#  10  koi_period         9564 non-null   float64
#  11  koi_period_err1    9110 non-null   float64
#  12  koi_period_err2    9110 non-null   float64
#  13  koi_time0bk        9564 non-null   float64
#  14  koi_time0bk_err1   9110 non-null   float64
#  15  koi_time0bk_err2   9110 non-null   float64
# ...

# %%
nasa_df.describe()
# Out:
#               kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# count  9.564000e+03  8054.000000    9564.000000    9564.000000    9564.000000
# mean   7.690628e+06     0.480829       0.208595       0.232748       0.197512
# std    2.653459e+06     0.476928       4.767290       0.422605       0.398142
# min    7.574500e+05     0.000000       0.000000       0.000000       0.000000
# 25%    5.556034e+06     0.000000       0.000000       0.000000       0.000000
# 50%    7.906892e+06     0.334000       0.000000       0.000000       0.000000
# 75%    9.873066e+06     0.998000       0.000000       0.000000       0.000000
# max    1.293514e+07     1.000000     465.000000       1.000000       1.000000
#
#        koi_fpflag_ec     koi_period  koi_period_err1  koi_period_err2  \
# count    9564.000000    9564.000000      9110.000000      9110.000000
# mean        0.120033      75.671358         0.002148        -0.002148
# ...

# %%
nasa_df.koi_score.describe()
# Out:
# count    8054.000000
# mean        0.480829
# std         0.476928
# min         0.000000
# 25%         0.000000
# 50%         0.334000
# 75%         0.998000
# max         1.000000
# Name: koi_score, dtype: float64

# %%
nasa_df.kepler_name.sample(25)
# Out:
# 6842    Kepler-1632 b
# 7541              NaN
# 1974     Kepler-380 c
# 7507              NaN
# 8696              NaN
# 4648              NaN
# 804               NaN
# 1489    Kepler-1073 b
# 5692              NaN
# 483               NaN
# 1725    Kepler-1167 b
# 5999              NaN
# 6278              NaN
# 562      Kepler-738 b
# 7356              NaN
# 8607              NaN
# 6771              NaN
# 9361              NaN
# 1997    Kepler-1228 b
# 2676              NaN
# 1281     Kepler-308 c
# 9477              NaN
# 133       Kepler-27 c
# 6665              NaN
# 422      Kepler-758 d
# Name: kepler_name, dtype: object

# %%
explain_df = pd.read_csv('columns_meaning.csv')

# %%
explain_df = explain_df.iloc[2:51,:1]

# %%
nasa_df = nasa_df.drop(columns=['kepler_name','koi_teq_err1','koi_teq_err2'])

# %%
nasa_df = nasa_df.dropna()

# %%
nasa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7803 entries, 0 to 9563
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              7803 non-null   int64
#  1   kepoi_name         7803 non-null   object
#  2   koi_disposition    7803 non-null   object
#  3   koi_pdisposition   7803 non-null   object
#  4   koi_score          7803 non-null   float64
#  5   koi_fpflag_nt      7803 non-null   int64
#  6   koi_fpflag_ss      7803 non-null   int64
#  7   koi_fpflag_co      7803 non-null   int64
#  8   koi_fpflag_ec      7803 non-null   int64
#  9   koi_period         7803 non-null   float64
#  10  koi_period_err1    7803 non-null   float64
#  11  koi_period_err2    7803 non-null   float64
#  12  koi_time0bk        7803 non-null   float64
#  13  koi_time0bk_err1   7803 non-null   float64
#  14  koi_time0bk_err2   7803 non-null   float64
#  15  koi_impact         7803 non-null   float64
# ...

# %%
nasa_df.sample(20)
# Out:
#          kepid kepoi_name koi_disposition koi_pdisposition  koi_score  \
# 712   11014932  K01432.03       CONFIRMED        CANDIDATE      0.999
# 2654  12404954  K00361.01       CONFIRMED        CANDIDATE      1.000
# 214    7373451  K00881.02       CONFIRMED        CANDIDATE      1.000
# 5594   5103998  K03660.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 6036   9634821  K02037.02       CANDIDATE        CANDIDATE      1.000
# 7419   5816144  K06137.02  FALSE POSITIVE   FALSE POSITIVE      0.000
# 2117   8636539  K02656.01       CANDIDATE        CANDIDATE      0.990
# 7784   8378922  K07028.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 4148   5340878  K04199.01       CONFIRMED        CANDIDATE      0.146
# 5357   6949061  K01960.02       CONFIRMED        CANDIDATE      0.992
# 5009   2717158  K03459.01       CANDIDATE        CANDIDATE      1.000
# 1139  11043136  K01644.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# ...

# %%
nasa_df.koi_disposition.value_counts()
# Out:
# FALSE POSITIVE    3735
# CONFIRMED         2332
# CANDIDATE         1736
# Name: koi_disposition, dtype: int64

# %%
explain_df
# Out:
#    # This file was produced by the NASA Exoplanet Archive  http://exoplanetarchive.ipac.caltech.edu
# 2                                                                    # COLUMN kepid:          KepID
# 3                                                                 # COLUMN kepoi_name:     KOI Name
# 4                                                              # COLUMN kepler_name:    Kepler Name
# 5                                           # COLUMN koi_disposition: Exoplanet Archive Disposition
# 6                                          # COLUMN koi_pdisposition: Disposition Using Kepler Data
# 7                                                        # COLUMN koi_score:      Disposition Score
# 8                                     # COLUMN koi_fpflag_nt:  Not Transit-Like False Positive Flag
# 9                                      # COLUMN koi_fpflag_ss:  Stellar Eclipse False Positive Flag
# ...

# %%
nasa_df.columns.to_list()
# Out:
# ['kepid',
#  'kepoi_name',
#  'koi_disposition',
#  'koi_pdisposition',
#  'koi_score',
#  'koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_fpflag_co',
#  'koi_fpflag_ec',
#  'koi_period',
#  'koi_period_err1',
#  'koi_period_err2',
#  'koi_time0bk',
#  'koi_time0bk_err1',
#  'koi_time0bk_err2',
#  'koi_impact',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_duration',
#  'koi_duration_err1',
#  'koi_duration_err2',
#  'koi_depth',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_teq',
#  'koi_insol',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_model_snr',
#  'koi_tce_plnt_num',
#  'koi_tce_delivname',
#  'koi_steff',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_slogg',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad',
#  'koi_srad_err1',
#  'koi_srad_err2',
#  'ra',
#  'dec',
#  'koi_kepmag']
